# %% [markdown]
# ### Decision Tree Model - Trip Departure Time

# %%
# Import Necessary Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier as DTR
from sklearn.metrics import roc_auc_score as rs
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
% matplotlib inline

# %%
# Load Dataset
df = pd.read_csv('../Data/trip_diary_filtered.csv', index_col=0)
df.head()
# Out:
#          PLSAM    SAMPN  PERNO  PLANO  OTAZ  OTRACT  DTAZ       DTRACT  \
# 0  30000560102  3000056      1      2  2626    5100  2627   9001205200
# 1  30000560103  3000056      1      3  2627    5200  2626   9001205100
# 2  30000560104  3000056      1      4  2626    5100  2627   9001205200
# 6  30000560202  3000056      2      2  2626    5100  2676  34003016000
# 7  30000560203  3000056      2      3  2676    6000  2626   9001205100
#
#    LTMODE_AGG  TRPDIST_HN    ...     WTAZ    WTRACT  STUDE  SCHOL  STAZ  \
# 0         1.0        2.81    ...     2627  9.00E+09     No    NaN   NaN
# 1         1.0        2.81    ...     2627  9.00E+09     No    NaN   NaN
# 2         1.0        2.81    ...     2627  9.00E+09     No    NaN   NaN
# 6         1.0       69.56    ...     2676  3.40E+10     No    NaN   NaN
# 7         1.0       66.12    ...     2676  3.40E+10     No    NaN   NaN
#
#    STRACT  PTRIPS_V  PTRIPS_T  PTRIPS_NM  PTRIPS_O
# 0     NaN         6         0          0         0
# 1     NaN         6         0          0         0
# 2     NaN         6         0          0         0
# 6     NaN         2         0          0         0
# 7     NaN         2         0          0         0
#
# [5 rows x 39 columns]

# %%
# Print Columns
df.columns
# Out:
# Index([u'PLSAM', u'SAMPN', u'PERNO', u'PLANO', u'OTAZ', u'OTRACT', u'DTAZ',
#        u'DTRACT', u'LTMODE_AGG', u'TRPDIST_HN', u'TRPDUR', u'TRP_DEP_HR',
#        u'TRP_DEP_MIN', u'TRP_ARR_HR', u'TRP_ARR_MIN', u'TOUR_PURP', u'HHSIZ',
#        u'INCOM', u'HHVEH', u'HHCHD', u'RESTY', u'GENDER', u'AGE_R', u'RACE',
#        u'EMPLY', u'WORKS', u'WDAYS', u'INDUS', u'OCCUP', u'WTAZ', u'WTRACT',
#        u'STUDE', u'SCHOL', u'STAZ', u'STRACT', u'PTRIPS_V', u'PTRIPS_T',
#        u'PTRIPS_NM', u'PTRIPS_O'],
#       dtype='object')

# %%
# Select columns for decision tree
data = df[['TRP_DEP_HR', 'TRP_DEP_MIN', 'TOUR_PURP', 'HHSIZ', 'INCOM', 'HHVEH', 'HHCHD', 'RESTY', 'GENDER', 'AGE_R', 'RACE',
       'EMPLY', 'WORKS', 'WDAYS', 'INDUS', 'OCCUP', 'WTAZ', 'WTRACT', 'STUDE', 'SCHOL', 'STAZ', 'STRACT']]
data.head()
# Out:
#    TRP_DEP_HR  TRP_DEP_MIN  TOUR_PURP  HHSIZ  INCOM  HHVEH  HHCHD  RESTY  \
# 0           7           29          9      6      5      3      2      1
# 1           8           35          9      6      5      3      2      1
# 2          12           37          1      6      5      3      2      1
# 6           6           15          1      6      5      3      2      1
# 7          18            7          1      6      5      3      2      1
#
#    GENDER        AGE_R  ...    WORKS WDAYS                 INDUS  \
# 0  Female  35-54 years  ...    Works  Five  EDUCATIONAL SERVICES
# 1  Female  35-54 years  ...    Works  Five  EDUCATIONAL SERVICES
# 2  Female  35-54 years  ...    Works  Five  EDUCATIONAL SERVICES
# 6    Male  35-54 years  ...    Works  Five         MANUFACTURING
# 7    Male  35-54 years  ...    Works  Five         MANUFACTURING
#
#                                            OCCUP  WTAZ    WTRACT STUDE SCHOL  \
# 0  OFFICE AND ADMINISTRATIVE SUPPORT OCCUPATIONS  2627  9.00E+09    No   NaN
# 1  OFFICE AND ADMINISTRATIVE SUPPORT OCCUPATIONS  2627  9.00E+09    No   NaN
# 2  OFFICE AND ADMINISTRATIVE SUPPORT OCCUPATIONS  2627  9.00E+09    No   NaN
# 6          PERSONAL CARE AND SERVICE OCCUPATIONS  2676  3.40E+10    No   NaN
# 7          PERSONAL CARE AND SERVICE OCCUPATIONS  2676  3.40E+10    No   NaN
#
#   STAZ STRACT
# 0  NaN    NaN
# 1  NaN    NaN
# 2  NaN    NaN
# 6  NaN    NaN
# 7  NaN    NaN
#
# [5 rows x 22 columns]

# %%
# Check columns with n/a values
data.isnull().any()
# Out:
# TRP_DEP_HR     False
# TRP_DEP_MIN    False
# TOUR_PURP      False
# HHSIZ          False
# INCOM          False
# HHVEH          False
# HHCHD          False
# RESTY          False
# GENDER         False
# AGE_R          False
# RACE           False
# EMPLY           True
# WORKS           True
# WDAYS           True
# INDUS           True
# OCCUP           True
# WTAZ            True
# WTRACT          True
# STUDE          False
# SCHOL           True
# STAZ            True
# STRACT          True
# dtype: bool

# %%
# Prepare Dataset
data = data.fillna('Not Applicable')
data.head()
# Out:
#    TRP_DEP_HR  TRP_DEP_MIN  TOUR_PURP  HHSIZ  INCOM  HHVEH  HHCHD  RESTY  \
# 0           7           29          9      6      5      3      2      1
# 1           8           35          9      6      5      3      2      1
# 2          12           37          1      6      5      3      2      1
# 6           6           15          1      6      5      3      2      1
# 7          18            7          1      6      5      3      2      1
#
#    GENDER        AGE_R       ...        WORKS WDAYS                 INDUS  \
# 0  Female  35-54 years       ...        Works  Five  EDUCATIONAL SERVICES
# 1  Female  35-54 years       ...        Works  Five  EDUCATIONAL SERVICES
# 2  Female  35-54 years       ...        Works  Five  EDUCATIONAL SERVICES
# 6    Male  35-54 years       ...        Works  Five         MANUFACTURING
# 7    Male  35-54 years       ...        Works  Five         MANUFACTURING
#
#                                            OCCUP  WTAZ    WTRACT STUDE  \
# 0  OFFICE AND ADMINISTRATIVE SUPPORT OCCUPATIONS  2627  9.00E+09    No
# 1  OFFICE AND ADMINISTRATIVE SUPPORT OCCUPATIONS  2627  9.00E+09    No
# 2  OFFICE AND ADMINISTRATIVE SUPPORT OCCUPATIONS  2627  9.00E+09    No
# 6          PERSONAL CARE AND SERVICE OCCUPATIONS  2676  3.40E+10    No
# 7          PERSONAL CARE AND SERVICE OCCUPATIONS  2676  3.40E+10    No
#
#             SCHOL            STAZ          STRACT
# 0  Not Applicable  Not Applicable  Not Applicable
# 1  Not Applicable  Not Applicable  Not Applicable
# 2  Not Applicable  Not Applicable  Not Applicable
# 6  Not Applicable  Not Applicable  Not Applicable
# 7  Not Applicable  Not Applicable  Not Applicable
#
# [5 rows x 22 columns]

# %%
#data['TRP_DEP_TIME'] = 60*data['TRP_DEP_HR'] + data['TRP_DEP_MIN']
data.drop(['TRP_DEP_MIN'], 1,inplace=True)
data.head()
# Out:
#    TRP_DEP_HR  TOUR_PURP  HHSIZ  INCOM  HHVEH  HHCHD  RESTY  GENDER  \
# 0           7          9      6      5      3      2      1  Female
# 1           8          9      6      5      3      2      1  Female
# 2          12          1      6      5      3      2      1  Female
# 6           6          1      6      5      3      2      1    Male
# 7          18          1      6      5      3      2      1    Male
#
#          AGE_R   RACE       ...        WORKS WDAYS                 INDUS  \
# 0  35-54 years  White       ...        Works  Five  EDUCATIONAL SERVICES
# 1  35-54 years  White       ...        Works  Five  EDUCATIONAL SERVICES
# 2  35-54 years  White       ...        Works  Five  EDUCATIONAL SERVICES
# 6  35-54 years  White       ...        Works  Five         MANUFACTURING
# 7  35-54 years  White       ...        Works  Five         MANUFACTURING
#
#                                            OCCUP  WTAZ    WTRACT STUDE  \
# 0  OFFICE AND ADMINISTRATIVE SUPPORT OCCUPATIONS  2627  9.00E+09    No
# 1  OFFICE AND ADMINISTRATIVE SUPPORT OCCUPATIONS  2627  9.00E+09    No
# 2  OFFICE AND ADMINISTRATIVE SUPPORT OCCUPATIONS  2627  9.00E+09    No
# 6          PERSONAL CARE AND SERVICE OCCUPATIONS  2676  3.40E+10    No
# 7          PERSONAL CARE AND SERVICE OCCUPATIONS  2676  3.40E+10    No
#
#             SCHOL            STAZ          STRACT
# 0  Not Applicable  Not Applicable  Not Applicable
# 1  Not Applicable  Not Applicable  Not Applicable
# 2  Not Applicable  Not Applicable  Not Applicable
# 6  Not Applicable  Not Applicable  Not Applicable
# 7  Not Applicable  Not Applicable  Not Applicable
#
# [5 rows x 21 columns]

# %%
# Select target variable and feature space
Y = data['TRP_DEP_HR']
X = pd.get_dummies(data.iloc[:, 1:])

X_train,X_test,y_train,y_test=train_test_split(X, Y, test_size=0.3, random_state=999)

# %%
X.columns
# Out:
# Index([u'TOUR_PURP', u'HHSIZ', u'INCOM', u'HHVEH', u'HHCHD', u'RESTY',
#        u'GENDER_Female', u'GENDER_Male', u'GENDER_RF', u'AGE_R_16-18 years',
#        ...
#        u'STAZ_99', u'STAZ_Location Outside of NYBPM Area',
#        u'STAZ_Not Applicable', u'STRACT_3.40E+10', u'STRACT_3.60E+10',
#        u'STRACT_3.61E+10', u'STRACT_9.00E+09', u'STRACT_9.01E+09',
#        u'STRACT_Location Outside of NYBPM Area', u'STRACT_Not Applicable'],
#       dtype='object', length=3066)

# %%
dtr = DTR()
dtr.fit(X_train,y_train)
pred = dtr.predict(X_test)

# %%
rs(pd.get_dummies(y_test), pd.get_dummies(pred))
# Out:
# 0.52515579727153583

# %%
Feature_importance=pd.DataFrame([list(X_train.columns),list(dtr.feature_importances_)]).T
Feature_importance.columns=["variables","importance"]
Feature_importance.sort_values(by="importance",ascending=False).iloc[:15,:]
# Out:
#                          variables  importance
# 2                            INCOM   0.0922346
# 3                            HHVEH   0.0685385
# 1                            HHSIZ   0.0575951
# 0                        TOUR_PURP   0.0411057
# 4                            HHCHD   0.0272525
# 5                            RESTY   0.0246217
# 12               AGE_R_35-54 years   0.0213423
# 13               AGE_R_55-64 years   0.0191846
# 26                      RACE_White   0.0174834
# 2488               WTRACT_3.61E+10   0.0129678
# 2486               WTRACT_3.40E+10    0.012479
# 14         AGE_R_65 years or older   0.0116605
# 11               AGE_R_25-34 years  0.00948588
# 85    OCCUP_MANAGEMENT OCCUPATIONS  0.00938243
# 17    RACE_African American, Black  0.00857763
